# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
blank_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(blank_img)

# %%
#rectangle 
cv2.rectangle(blank_img,pt1=(150,80), pt2=(510,100), color=(0,255,0), thickness=1)
plt.imshow(blank_img)

# %%
cv2.circle(blank_img, center=(100,100), radius=25, color=(123,22,178), thickness=9)
plt.imshow(blank_img)

# %%
cv2.circle(blank_img, center=(200,500), radius=25, color=(123,22,178), thickness=-2)
plt.imshow(blank_img)

# %%
cv2.line(blank_img, pt1=(0,0), pt2=(512,512), color=(100,100,100), thickness=12)
plt.imshow(blank_img)

# %%
blank_img2 = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(blank_img2)

# %%
#TEXT
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(blank_img2, text = 'Hello', org=(50,100), fontFace =font, fontScale = 4, color=(255,255,120))
plt.imshow(blank_img2)
