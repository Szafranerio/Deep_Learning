# %%
import torch
import numpy as np
import random

# %%
np.random.seed(42)
torch.manual_seed(42)

# %%
arr = np.random.randint(0,6, size=6)
arr
# Out:
# array([3, 4, 2, 4, 4, 1])

# %%
x = torch.from_numpy(arr)
x
# Out:
# tensor([3, 4, 2, 4, 4, 1])

# %%
x = torch.reshape(x, shape=(3,2))
x
# Out:
# tensor([[3, 4],
#         [2, 4],
#         [4, 1]])

# %%
x[:,1:]
# Out:
# tensor([[4],
#         [4],
#         [1]])

# %%
x**2
# Out:
# tensor([[ 9, 16],
#         [ 4, 16],
#         [16,  1]])

# %%
y = torch.randint(low=0, high=6, size=(2,3))
y
# Out:
# tensor([[0, 5, 4],
#         [4, 0, 5]])

# %%
print(x.size())
print(y.size())
# Out:
# torch.Size([3, 2])
# torch.Size([2, 3])

# %%
torch.matmul(x,y)
# Out:
# tensor([[16, 15, 32],
#         [16, 10, 28],
#         [ 4, 20, 21]])

# %%
x @ y
# Out:
# tensor([[16, 15, 32],
#         [16, 10, 28],
#         [ 4, 20, 21]])
